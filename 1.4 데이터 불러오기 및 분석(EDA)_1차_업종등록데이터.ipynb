# %% [markdown]
# # 안녕하세요^^
# ## '서울시 생활정보 기반 대중교통 수요 분석 ' 과정에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.
# ## "구별 업종 등록 데이터" 를 확인해 보도록 하겠습니다

# %%
# 필요 라이브러리부터 설치합니다.
# %pip install pandas seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 기본/추가 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * business_type.csv
#
# [데이터 소개]
# * 서울 시 구별 등록 업종 상위 10개 데이터
#     * 택시운송업
#     * 한식일반음식점업
#     * 용달 화물자동차 운송업
#     * 부동산 중개 및 대리업
#     * 두발미용업
#     * 커피전문점
#     * 남녀용 겉옷 및 셔츠 도매업
#     * 기타주점업
#     * 일반 교과 학원
#     * 한식 육류요리 전문점
#
# [변수 소개]
# * 다수 업종 상위 1~10

# %% [markdown]
# ---

# %% [markdown]
# # 1.데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)
# * csv : pd.read_csv("파일이름. csv")
# * txt : pd.read_csv("파일이름. csv", sep="구분자")
# * xlsx : pd.read_excel('파일이름.xlsx')
# * pickle : pd.read_pickle("파일이름.pkl") <br>
#  [참고] pickle은 파이썬의 모든 객체를 파일로 저장할 수 있는 방법으로 DataFrame,List,Dict 등 모든 객체 저장 가능(특히 sklearn라이브러리를 통해 모델을 학습시키고, 저장할 때 많이 사용)

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * 1.4 business_type.csv
#
# [데이터 소개]
# * 서울시 업종 등록 데이터

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * '1.4 business_type.csv'파일을 'seoul_business' 변수에 저장하고 그 데이터를 확인하세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 ',' 입니다
#         * UTF-8 인코더를 사용해 주세요

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import pandas as pd
seoul_business = pd.read_csv('1.4 business_type.csv', sep=",",na_values = '-',encoding = "UTF-8")

# %%
seoul_business
# Out:
#      자치구     동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3   다수업종 상위10.4  \
# 0    자치구     동     택시운송업       택시운송업  한식 일반 음식점업  한식 일반 음식점업  용달 화물자동차 운송업
# 1    자치구     동      사업체수        종사자수        사업체수        종사자수          사업체수
# 2     합계    합계    47,176      76,701      29,225     100,183        28,494
# 3    종로구    소계       215         215       1,548       5,912           618
# 4    종로구   사직동         7           7         230         982            12
# ..   ...   ...       ...         ...         ...         ...           ...
# 446  강동구  성내3동       120         120         135         390            73
# 447  강동구  둔촌2동       117         436          63         249            89
# 448  강동구  암사1동       209         372          71         195           153
# 449  강동구  천호2동       157         187         152         509           144
# 450  강동구    길동     1,441       1,557         152         436           217
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# # 2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [실습문제2] 기본 정보 확인하기
# * 'seoul_moving' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head' 등 전부 활용해 보겠습니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   자치구           451 non-null    object
#  1   동             451 non-null    object
#  2   다수업종 상위10     450 non-null    object
#  3   다수업종 상위10.1   450 non-null    object
#  4   다수업종 상위10.2   451 non-null    object
#  5   다수업종 상위10.3   451 non-null    object
#  6   다수업종 상위10.4   448 non-null    object
#  7   다수업종 상위10.5   448 non-null    object
#  8   다수업종 상위10.6   451 non-null    object
#  9   다수업종 상위10.7   451 non-null    object
#  10  다수업종 상위10.8   450 non-null    object
#  11  다수업종 상위10.9   450 non-null    object
#  12  다수업종 상위10.10  451 non-null    object
#  13  다수업종 상위10.11  451 non-null    object
#  14  다수업종 상위10.12  369 non-null    object
#  15  다수업종 상위10.13  369 non-null    object
#  16  다수업종 상위10.14  443 non-null    object
#  17  다수업종 상위10.15  443 non-null    object
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.describe()
# Out:
#         자치구    동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3 다수업종 상위10.4  \
# count   451  451       450         450         451         451         448
# unique   27  425       225         279         176         305         176
# top     송파구   소계        71          11          24         104          27
# freq     28   25         7           7          11           6           8
#
#        다수업종 상위10.5 다수업종 상위10.6 다수업종 상위10.7  ... 다수업종 상위10.10 다수업종 상위10.11  \
# count          448         451         451  ...          451          451
# unique         179         142         205  ...          131          239
# top             56          40          54  ...           13           16
# freq             9          11           9  ...           18            8
#
#        다수업종 상위10.12 다수업종 상위10.13 다수업종 상위10.14 다수업종 상위10.15 다수업종 상위10.16  \
# count           369          369          443          443          441
# unique           68          146          126          188          112
# ...

# %%
seoul_business.head()
# Out:
#    자치구    동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3   다수업종 상위10.4  \
# 0  자치구    동     택시운송업       택시운송업  한식 일반 음식점업  한식 일반 음식점업  용달 화물자동차 운송업
# 1  자치구    동      사업체수        종사자수        사업체수        종사자수          사업체수
# 2   합계   합계    47,176      76,701      29,225     100,183        28,494
# 3  종로구   소계       215         215       1,548       5,912           618
# 4  종로구  사직동         7           7         230         982            12
#
#     다수업종 상위10.5   다수업종 상위10.6   다수업종 상위10.7  ... 다수업종 상위10.10 다수업종 상위10.11  \
# 0  용달 화물자동차 운송업  부동산 중개 및 대리업  부동산 중개 및 대리업  ...        커피전문점        커피전문점
# 1          종사자수          사업체수          종사자수  ...         사업체수         종사자수
# 2        29,356        24,013        42,636  ...       16,255       57,322
# 3           646           549           889  ...          948        3,613
# 4            12            57            96  ...          124          525
#
#       다수업종 상위10.12     다수업종 상위10.13 다수업종 상위10.14 다수업종 상위10.15 다수업종 상위10.16  \
# ...

# %%
store_list = ['커피 전문점', '기타주점업']

# %% [markdown]
# #### [실습문제3] 데이터 확인 및 처리
#
# * 데이터를 보았을때, 어느 데이터를 가져와야 할지 생각 해 봅시다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business = seoul_business[(seoul_business['동'] == '소계') | (seoul_business['동'] == '합계')]

# %%
seoul_business = seoul_business.reset_index(drop = True)
seoul_business
# Out:
#      자치구   동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3 다수업종 상위10.4  \
# 0     합계  합계    47,176      76,701      29,225     100,183      28,494
# 1    종로구  소계       215         215       1,548       5,912         618
# 2     중구  소계       230         235       1,588       6,414         300
# 3    용산구  소계       416         523         857       2,987         455
# 4    성동구  소계     1,200       2,527         956       2,785       1,072
# 5    광진구  소계     1,119       1,744         963       2,861         968
# 6   동대문구  소계     1,546       2,093       1,236       3,566       1,431
# 7    중랑구  소계     3,634       6,262         991       2,479       1,804
# 8    성북구  소계     1,835       2,643         973       2,822       1,312
# 9    강북구  소계     1,713       2,589         965       2,663       1,024
# 10   도봉구  소계     2,993       5,783         672       2,009       1,571
# 11   노원구  소계     4,114       6,074         866       2,650       1,730
# ...

# %%
seoul_business = seoul_business.fillna(0)
seoul_business.head()
# Out:
#    자치구   동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3 다수업종 상위10.4  \
# 0   합계  합계    47,176      76,701      29,225     100,183      28,494
# 1  종로구  소계       215         215       1,548       5,912         618
# 2   중구  소계       230         235       1,588       6,414         300
# 3  용산구  소계       416         523         857       2,987         455
# 4  성동구  소계     1,200       2,527         956       2,785       1,072
#
#   다수업종 상위10.5 다수업종 상위10.6 다수업종 상위10.7  ... 다수업종 상위10.10 다수업종 상위10.11  \
# 0      29,356      24,013      42,636  ...       16,255       57,322
# 1         646         549         889  ...          948        3,613
# 2         333         576       1,152  ...          869        3,542
# 3         466         791       1,214  ...          634        2,076
# 4       1,161         801       1,453  ...          547        1,859
#
#   다수업종 상위10.12 다수업종 상위10.13 다수업종 상위10.14 다수업종 상위10.15 다수업종 상위10.16  \
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business = seoul_business.drop(['동'],axis=1)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
for i in range (1,21):
    seoul_business.iloc[:,i] = seoul_business.iloc[:,i].str.replace(',' , "").astype('int')

# %%
seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   자치구           26 non-null     object
#  1   다수업종 상위10     26 non-null     object
#  2   다수업종 상위10.1   26 non-null     object
#  3   다수업종 상위10.2   26 non-null     object
#  4   다수업종 상위10.3   26 non-null     object
#  5   다수업종 상위10.4   26 non-null     object
#  6   다수업종 상위10.5   26 non-null     object
#  7   다수업종 상위10.6   26 non-null     object
#  8   다수업종 상위10.7   26 non-null     object
#  9   다수업종 상위10.8   26 non-null     object
#  10  다수업종 상위10.9   26 non-null     object
#  11  다수업종 상위10.10  26 non-null     object
#  12  다수업종 상위10.11  26 non-null     object
#  13  다수업종 상위10.12  26 non-null     object
#  14  다수업종 상위10.13  26 non-null     object
#  15  다수업종 상위10.14  26 non-null     object
#  16  다수업종 상위10.15  26 non-null     object
#  17  다수업종 상위10.16  26 non-null     object
# ...

# %% [markdown]
# ## seoul_business

# %%
seoul_business.columns = seoul_business.columns = ['자치구','택시운송업 사업체수', '택시운송업 종사자수', '한식 일반 음식점업 사업체수', '한식 일반 음식점업 종사자수','용달 화물자동차 운송업 사업체수',
            '용달 화물자동차 운송업 종사자수', '부동산 중개 및 대리업 사업체수', '부동산 중개 및 대리업 종사자수', '두발미용업 사업체수',
            '두발미용업 종사자수', '커피전문점 사업체수', '커피전문점 종사자수', '남녀용 겉옷 및 셔츠 도매업 사업체수', '남녀용 겉옷 및 셔츠 도매업 종사자수',
            '기타주점업 사업체수', '기타주점업 종사자수', '일반 교과 학원 사업체수', '일반 교과 학원 종사자수', '한식 육류요리 전문점 사업체수',
            '한식 육류요리 전문점 종사자수']

# %%
#a = seoul_business[['자치구','다수업종 상위10','다수업종 상위10.1']]

# %%
seoul_business
# Out:
#      자치구 택시운송업 사업체수 택시운송업 종사자수 한식 일반 음식점업 사업체수 한식 일반 음식점업 종사자수  \
# 0     합계      47176      76701           29225          100183
# 1    종로구        215        215            1548            5912
# 2     중구        230        235            1588            6414
# 3    용산구        416        523             857            2987
# 4    성동구       1200       2527             956            2785
# 5    광진구       1119       1744             963            2861
# 6   동대문구       1546       2093            1236            3566
# 7    중랑구       3634       6262             991            2479
# 8    성북구       1835       2643             973            2822
# 9    강북구       1713       2589             965            2663
# 10   도봉구       2993       5783             672            2009
# 11   노원구       4114       6074             866            2650
# 12   은평구       3108       4430             881            2585
# 13  서대문구       1747       2677             863            2694
# ...

# %%
# 해당 데이터프레임을 'df_seoul_business.csv' 파일로 저장하세요.

fpath = './df_seoul_business.csv'
seoul_business.to_csv(fpath, index=False, encoding='utf-8-sig')

# %% [markdown]
# ---

# %% [markdown]
# # 3.데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='nanum')
sns.set(font="NanumGothicCoding",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [실습문제4] 데이터 분포 알아보기
# * 다양한 변수를 기준으로 그래프를 그려보고 인사이트를 도출해보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.drop('자치구', axis=1, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font="AppleGothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid',
        font_scale = 1)

colormap = plt.cm.PuBu
plt.figure(figsize=(40, 20))
plt.title("subset1", y = 1.05, size = 15)
sns.heatmap(seoul_business.astype(float).corr(), linewidths = 0.1, vmax = 0.5,
           square = True, cmap = colormap, linecolor = "white", annot = True, annot_kws = {"size" : 10})
# Out:
# <AxesSubplot:title={'center':'subset1'}>

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1. 각 사업체 수 마다 매우 높은 상관관계가 나온다.
# 2.
# 3.

# %% [markdown]
# ---
